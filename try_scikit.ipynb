# %%
import pandas as pd
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %%
data = load_iris()

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)
# count         150.000000        150.000000         150.000000  \
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
df['target'] = data.target_names[data.target]

# %%
df[df.target=='virginica'].plot.scatter(x='sepal length (cm)', y='sepal width (cm)')
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %%
fig, ax = plt.subplots()
for name, group in df.groupby('target'):
    ax.plot(group['sepal length (cm)'], group['sepal width (cm)'], marker='o', linestyle='', ms=8, label=name)
ax.legend()
plt.show()

# %%
import mpl_toolkits.mplot3d
from sklearn.decomposition import PCA

# %%
iris = load_iris()
X = iris.data[:, :2]
Y = iris.target

# %%
x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5

# %%
plt.figure(2, figsize=(8, 6))
plt.clf()

# %%
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Set1, edgecolors="k")
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
# Out:
# Text(0, 0.5, 'Sepal width')

# %%
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())
# Out:
# ([], [])

# %%
fig = plt.figure(1, figsize=(8, 6))
ax = fig.add_subplot(111, projection="3d", elev=-150, azim=110)

# %%
X_reduced = PCA(n_components=3).fit_transform(iris.data)
ax.scatter(
    X_reduced[:, 0],
    X_reduced[:, 1],
    X_reduced[:, 2],
    c=Y,
    cmap=plt.cm.Set1,
    edgecolor="k",
    s=40
)

# %%
ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
ax.xaxis.set_ticklabels([])
ax.set_ylabel("2nd eigenvector")
ax.set_zlabel("3rd eigenvector")
ax.zaxis.set_ticklabels([])
# Out:
# [Text(-0.8, 0.05650353162282815, ''),
#  Text(-0.6000000000000001, 0.04150369967485047, ''),
#  Text(-0.4, 0.026753369474109362, ''),
#  Text(-0.19999999999999996, 0.012246367185338565, ''),
#  Text(0.0, -0.0020232790004997246, ''),
#  Text(0.19999999999999996, -0.016061347062783785, ''),
#  Text(0.40000000000000013, 0, ''),
#  Text(0.6000000000000001, 0, ''),
#  Text(0.8, 0, ''),
#  Text(1.0, 0, '')]

# %%
plt.show()
